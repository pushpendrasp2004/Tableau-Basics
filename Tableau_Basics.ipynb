# %% [markdown]
# 1. Explain what Tableau is and why it is preferred over traditional spreadsheet tools for data analysis.
#
# Also mention any two industries where Tableau is commonly used and explain one use case.
# - Tableau is a powerful data visualization and business intelligence tool used to analyze and present data in interactive dashboards.
#
# Why preferred over spreadsheets (e.g., Microsoft Excel):
# Handles large datasets efficiently
# Provides interactive visualizations
# Enables real-time insights
# Supports drag-and-drop analytics
# Better for data storytelling
# Industries & Use Case:
# Retail → Analyze sales trends and customer behavior
# Healthcare → Track patient data and hospital performance
#
# Use case: In retail, Tableau helps identify top-selling products and regions, improving sales strategy.
#
# 2. After connecting to the Sample – Superstore dataset:
#
# a) List the main types of fields available (examples: time-based, geographical, numerical).
# b) Identify any four Dimensions and any four Measures from the dataset.
#
# Hint: Look at the Data Pane on the left side of Tableau and observe blue (Dimensions) and green (Measures)
# fields.
#
# - a) Types of fields:
# Time-based: Order Date, Ship Date
# Geographical: Country, State, Region
# Numerical: Sales, Profit, Quantity
# (b) Dimensions & Measures
#
# Dimensions (any 4):
#
# Category
# Sub-Category
# Region
# Customer Name
#
# Measures (any 4):
#
# Sales
# Profit
# Quantity
# Discount
#
# 3. Create a Bar Chart showing Total Sales by Category.
#
# Explain:
#
# Which field goes to Rows
#
# Which field goes to Columns
#
# Which aggregation is applied to Sales
#
# Hint: Drag Category and Sales into the view and observe Tableau’s default behavior.
#
# - Rows: Category
# Columns: Sales
# Aggregation: SUM (default)
#
# Tableau automatically applies SUM(Sales).
#
# 4. What insight can be gained by comparing Sales and Profit together?
#
# Then explain how you would create a chart to analyze Profit by Sub-Category.
#
# Hint: Use Sub-Category as a Dimension and Profit as a Measure.
# - Insight:
# High sales ≠ high profit
# Helps identify loss-making products
# Chart for Profit by Sub-Category:
# Drag Sub-Category → Rows
# Drag Profit → Columns
# Use Bar Chart
#
# 5.  Create a Line Chart to show Sales Trend over Order Date.
#
# Which date level would you choose (Year / Quarter / Month)?
#
# Why are line charts suitable for time-based analysis?
#
# Hint: Drag Order Date and change its date hierarchy from Year to Month if needed.
# - Date Level: Month (best choice)
# Why Month?
# Shows detailed trend without overcrowding
# Better than yearly (too broad) or daily (too dense)
# Why line charts?
# Show continuous trends over time
# Highlight patterns & seasonality
#
# 6.  Apply a Basic Filter to display data only for:
#
# Region = “West”
#
# Category = “Technology”
#
# Explain the steps and mention which shelf is used.
#
# Hint: Drag the required fields to the Filters shelf and select appropriate values.
# - Steps:
# Drag Region → Filters shelf
# Select West
# Drag Category → Filters shelf
# Select Technology
#
#  Shelf used: Filters Shelf
#
# 7. Explain the business importance of geographical analysis.
#
# Then describe how you would create a Map showing Sales by State using Sample – Superstore.
#
# Hint:  Use State and Sales. Tableau automatically detects geographic fields.
# -  Business Importance:
# Identify regional performance
# Helps in targeted marketing
# Improves resource allocation
# Steps to create Map (Sales by State):
# Drag State → View
# Drag Sales → Color/Size
# Tableau creates map automatically
#
# 8. What is the difference between a Worksheet and a Dashboard in Tableau?
#
# Why is a dashboard more useful for decision-makers?
# -
# | Feature       | Worksheet    | Dashboard       |
# | ------------- | ------------ | --------------- |
# | Content       | Single chart | Multiple charts |
# | Purpose       | Analysis     | Summary         |
# | Interactivity | Limited      | High            |
#
# 9.  What is Tableau Prep, and why is it important in real-world data projects?
#
# What is Tableau Prep, and why is it important in real-world data projects?
#
# Then explain how you would:
#
# Remove null values
#
# Remove duplicate records
#
# Change incorrect data types (Answer in steps, no tool access required.)
#
# -  Tableau Prep is used for cleaning and transforming data before analysis.
#
# Importance:
# Ensures accurate data
# Improves data quality
# Saves analysis time
# Steps:
#
# 1. Remove null values:
#
# Use filter → Exclude Null values
#
# 2. Remove duplicates:
#
# Use Remove Duplicates option
#
# 3. Change data types:
#
# Select field → Change data type (string, number, date)
#
# 10.  A retail manager wants answers to the following:
#
# Which category generates the highest profit?
#
# Which region performs poorly?
#
# How does sales change over time?
#
# a) Mention which charts you would use
# b) Identify one key insight that management could derive
# c) Explain how this helps in business decision-making
#
# - a) Charts to use:
#
#
# Highest profit → Bar Chart
#
#
# Poor region → Bar Chart / Map
#
#
# Sales over time → Line Chart
#
#
# (b) Key Insight:
#
#
# Some categories generate high sales but low profit
#
#
# (c) Business Decision Impact:
#
#
# Focus on profitable categories
#
#
# Improve performance in weak regions
#
#
# Plan inventory based on trends
